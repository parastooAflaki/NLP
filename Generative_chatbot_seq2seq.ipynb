# %% [markdown]
# <a href="https://colab.research.google.com/github/parastooAflaki/NLP/blob/master/Generative_chatbot_seq2seq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import random
data_path = "/content/sample_data/human_text.txt"
data_path2 = "/content/sample_data/robot_text.txt"

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import LSTM
from numpy import array

# %%
# Defining lines as a list of each line
with open(data_path, 'r', encoding='utf-8') as f:
  lines = f.read().split('\n')
with open(data_path2, 'r', encoding='utf-8') as f:
  lines2 = f.read().split('\n')

# %%
lines = [re.sub(r"\[\w+\]",'hi',line) for line in lines]
lines = [" ".join(re.findall(r"\w+",line)) for line in lines]
lines2 = [re.sub(r"\[\w+\]",'',line) for line in lines2]
lines2 = [" ".join(re.findall(r"\w+",line)) for line in lines2]
# grouping lines by response pair
pairs = list(zip(lines,lines2))
#random.shuffle(pairs)

# %%
input_docs = []
target_docs = []
input_tokens = set()
target_tokens = set()
for line in pairs[:400]:
  input_doc, target_doc = line[0], line[1]
  # Appending each input sentence to input_docs
  input_docs.append(input_doc)
  # Splitting words from punctuation  
  target_doc = " ".join(re.findall(r"[\w']+|[^\s\w]", target_doc))
  # Redefine target_doc below and append it to target_docs
  target_doc = '<START> ' + target_doc + ' <END>'
  target_docs.append(target_doc)
  
  # Now we split up each sentence into words and add each unique word to our vocabulary set

  for token in re.findall(r"[\w']+|[^\s\w]", input_doc):
    if token not in input_tokens:
      input_tokens.add(token)
  for token in target_doc.split():
    if token not in target_tokens:
      target_tokens.add(token)
input_tokens = sorted(list(input_tokens))
target_tokens = sorted(list(target_tokens))
num_encoder_tokens = len(input_tokens)
num_decoder_tokens = len(target_tokens)

# %%
import numpy as np
input_features_dict = dict(
    [(token, i) for i, token in enumerate(input_tokens)])
target_features_dict = dict(
    [(token, i) for i, token in enumerate(target_tokens)])
reverse_input_features_dict = dict(
    (i, token) for token, i in input_features_dict.items())
reverse_target_features_dict = dict(
    (i, token) for token, i in target_features_dict.items())

# %%
#Maximum length of sentences in input and target documents
max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_doc)) for input_doc in input_docs])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_doc)) for target_doc in target_docs])
encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):
    for timestep, token in enumerate(re.findall(r"[\w']+|[^\s\w]", input_doc)):
        #Assign 1. for the current line, timestep, & word in encoder_input_data
        encoder_input_data[line, timestep, input_features_dict[token]] = 1.
    
    for timestep, token in enumerate(target_doc.split()):
        decoder_input_data[line, timestep, target_features_dict[token]] = 1.
        if timestep > 0:
            decoder_target_data[line, timestep - 1, target_features_dict[token]] = 1.

# %%
from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model
#Dimensionality
dimensionality = 256
#The batch size and number of epochs
batch_size = 10
epochs = 600
#Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(dimensionality, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
encoder_states = [state_hidden, state_cell]
#Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(dimensionality, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model
#Dimensionality
dimensionality = 256
#The batch size and number of epochs
batch_size = 10
epochs = 600
#Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(dimensionality, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
encoder_states = [state_hidden, state_cell]
#Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(dimensionality, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

#Model
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
#Compiling
training_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'], sample_weight_mode='temporal')
#Training
training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)
training_model.save('training_model.h5')
# Out:
# Epoch 1/600
# 32/32 [==============================] - 1s 35ms/step - loss: 1.2204 - accuracy: 0.0229 - val_loss: 1.3421 - val_accuracy: 0.0200
# Epoch 2/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.1366 - accuracy: 0.0240 - val_loss: 1.3746 - val_accuracy: 0.0203
# Epoch 3/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.1207 - accuracy: 0.0240 - val_loss: 1.4422 - val_accuracy: 0.0200
# Epoch 4/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.1268 - accuracy: 0.0230 - val_loss: 1.4700 - val_accuracy: 0.0210
# Epoch 5/600
# 32/32 [==============================] - 1s 16ms/step - loss: 1.0977 - accuracy: 0.0242 - val_loss: 1.4675 - val_accuracy: 0.0198
# Epoch 6/600
# 32/32 [==============================] - 1s 16ms/step - loss: 1.0878 - accuracy: 0.0241 - val_loss: 1.4874 - val_accuracy: 0.0198
# Epoch 7/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0803 - accuracy: 0.0241 - val_loss: 1.5225 - val_accuracy: 0.0210
# Epoch 8/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0666 - accuracy: 0.0249 - val_loss: 1.5211 - val_accuracy: 0.0210
# Epoch 9/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0576 - accuracy: 0.0243 - val_loss: 1.5391 - val_accuracy: 0.0207
# Epoch 10/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0491 - accuracy: 0.0249 - val_loss: 1.5644 - val_accuracy: 0.0210
# Epoch 11/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0412 - accuracy: 0.0254 - val_loss: 1.5480 - val_accuracy: 0.0227
# Epoch 12/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0301 - accuracy: 0.0260 - val_loss: 1.5716 - val_accuracy: 0.0220
# Epoch 13/600
# 32/32 [==============================] - 1s 16ms/step - loss: 1.0190 - accuracy: 0.0271 - val_loss: 1.5584 - val_accuracy: 0.0217
# Epoch 14/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0103 - accuracy: 0.0276 - val_loss: 1.5855 - val_accuracy: 0.0207
# Epoch 15/600
# 32/32 [==============================] - 0s 15ms/step - loss: 1.0004 - accuracy: 0.0284 - val_loss: 1.5788 - val_accuracy: 0.0207
# Epoch 16/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.9907 - accuracy: 0.0291 - val_loss: 1.5759 - val_accuracy: 0.0223
# Epoch 17/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.9725 - accuracy: 0.0307 - val_loss: 1.5491 - val_accuracy: 0.0243
# Epoch 18/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.9585 - accuracy: 0.0322 - val_loss: 1.5573 - val_accuracy: 0.0225
# Epoch 19/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.9454 - accuracy: 0.0339 - val_loss: 1.5517 - val_accuracy: 0.0235
# Epoch 20/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.9265 - accuracy: 0.0356 - val_loss: 1.5622 - val_accuracy: 0.0245
# Epoch 21/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.9097 - accuracy: 0.0364 - val_loss: 1.5884 - val_accuracy: 0.0253
# Epoch 22/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.8938 - accuracy: 0.0377 - val_loss: 1.5785 - val_accuracy: 0.0245
# Epoch 23/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.8767 - accuracy: 0.0394 - val_loss: 1.5871 - val_accuracy: 0.0245
# Epoch 24/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0
600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0434 - accuracy: 0.1955 - val_loss: 2.2475 - val_accuracy: 0.0180
# Epoch 242/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0392 - accuracy: 0.1959 - val_loss: 2.2329 - val_accuracy: 0.0188
# Epoch 243/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0419 - accuracy: 0.1943 - val_loss: 2.2458 - val_accuracy: 0.0188
# Epoch 244/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0415 - accuracy: 0.1959 - val_loss: 2.2422 - val_accuracy: 0.0188
# Epoch 245/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0389 - accuracy: 0.1952 - val_loss: 2.2554 - val_accuracy: 0.0188
# Epoch 246/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0423 - accuracy: 0.1955 - val_loss: 2.2486 - val_accuracy: 0.0172
# Epoch 247/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0383 - accuracy: 0.1961 - val_loss: 2.2430 - val_accuracy: 0.0170
# Epoch 248/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0402 - accuracy: 0.1947 - val_loss: 2.2460 - val_accuracy: 0.0188
# Epoch 249/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0418 - accuracy: 0.1954 - val_loss: 2.2401 - val_accuracy: 0.0175
# Epoch 250/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0361 - accuracy: 0.1974 - val_loss: 2.2328 - val_accuracy: 0.0182
# Epoch 251/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0387 - accuracy: 0.1961 - val_loss: 2.2515 - val_accuracy: 0.0168
# Epoch 252/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0356 - accuracy: 0.1973 - val_loss: 2.2450 - val_accuracy: 0.0172
# Epoch 253/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0401 - accuracy: 0.1954 - val_loss: 2.2431 - val_accuracy: 0.0172
# Epoch 254/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0397 - accuracy: 0.1960 - val_loss: 2.2460 - val_accuracy: 0.0175
# Epoch 255/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0392 - accuracy: 0.1957 - val_loss: 2.2577 - val_accuracy: 0.0185
# Epoch 256/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0367 - accuracy: 0.1972 - val_loss: 2.2526 - val_accuracy: 0.0185
# Epoch 257/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0364 - accuracy: 0.1971 - val_loss: 2.2585 - val_accuracy: 0.0178
# Epoch 258/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0370 - accuracy: 0.1969 - val_loss: 2.2656 - val_accuracy: 0.0180
# Epoch 259/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0357 - accuracy: 0.1972 - val_loss: 2.2717 - val_accuracy: 0.0175
# Epoch 260/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0343 - accuracy: 0.1970 - val_loss: 2.2755 - val_accuracy: 0.0175
# Epoch 261/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0362 - accuracy: 0.1969 - val_loss: 2.2807 - val_accuracy: 0.0182
# Epoch 262/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0353 - accuracy: 0.1972 - val_loss: 2.2654 - val_accuracy: 0.0185
# Epoch 263/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0320 - accuracy: 0.1987 - val_loss: 2.2564 - val_accuracy: 0.0170
# Epoch 264/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0281 - accuracy: 0.2004 - val_loss: 2.2619 - val_accuracy: 0.0172
# Epoch 265/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0282 - accuracy: 0.1997 - val_loss: 2.2628 - val_accuracy: 0.0162
# Epoch 266/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0318 - accuracy: 0.1982 - val_loss: 2.2670 - val_accuracy: 0.0185
# Epoch 267/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0345 - accuracy: 0.1975 - val_loss: 2.2572 - val_accuracy: 0.0188
# Epoch 268/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0354 - accuracy: 0.1972 - val_loss: 2.2702 - val_accuracy: 0.0172
# Epoch 269/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0324 - accuracy: 0.1985 - val_loss: 2.2786 - val_accuracy: 0.0178
# Epoch 270/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0318 - accuracy: 0.1984 - val_loss: 2.2845 - val_accuracy: 0.0170
# Epoch 271/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0311 - accuracy: 0.1991 - val_loss: 2.2776 - val_accuracy: 0.0185
# Epoch 272/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.
600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0217 - accuracy: 0.2023 - val_loss: 2.3081 - val_accuracy: 0.0178
# Epoch 304/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0228 - accuracy: 0.2031 - val_loss: 2.3146 - val_accuracy: 0.0168
# Epoch 305/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0220 - accuracy: 0.2025 - val_loss: 2.3422 - val_accuracy: 0.0180
# Epoch 306/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0195 - accuracy: 0.2036 - val_loss: 2.3224 - val_accuracy: 0.0165
# Epoch 307/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0197 - accuracy: 0.2029 - val_loss: 2.3362 - val_accuracy: 0.0162
# Epoch 308/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0206 - accuracy: 0.2031 - val_loss: 2.3172 - val_accuracy: 0.0165
# Epoch 309/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0206 - accuracy: 0.2031 - val_loss: 2.2892 - val_accuracy: 0.0158
# Epoch 310/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0204 - accuracy: 0.2027 - val_loss: 2.3015 - val_accuracy: 0.0170
# Epoch 311/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0225 - accuracy: 0.2026 - val_loss: 2.3228 - val_accuracy: 0.0190
# Epoch 312/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0220 - accuracy: 0.2034 - val_loss: 2.2941 - val_accuracy: 0.0170
# Epoch 313/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0175 - accuracy: 0.2051 - val_loss: 2.3177 - val_accuracy: 0.0180
# Epoch 314/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0170 - accuracy: 0.2041 - val_loss: 2.3067 - val_accuracy: 0.0160
# Epoch 315/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0204 - accuracy: 0.2035 - val_loss: 2.3044 - val_accuracy: 0.0188
# Epoch 316/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0224 - accuracy: 0.2023 - val_loss: 2.3133 - val_accuracy: 0.0185
# Epoch 317/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0153 - accuracy: 0.2051 - val_loss: 2.3126 - val_accuracy: 0.0172
# Epoch 318/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0171 - accuracy: 0.2034 - val_loss: 2.3074 - val_accuracy: 0.0175
# Epoch 319/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0183 - accuracy: 0.2039 - val_loss: 2.3106 - val_accuracy: 0.0165
# Epoch 320/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0161 - accuracy: 0.2052 - val_loss: 2.3208 - val_accuracy: 0.0195
# Epoch 321/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0199 - accuracy: 0.2031 - val_loss: 2.3294 - val_accuracy: 0.0165
# Epoch 322/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0141 - accuracy: 0.2058 - val_loss: 2.3278 - val_accuracy: 0.0175
# Epoch 323/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0130 - accuracy: 0.2055 - val_loss: 2.3346 - val_accuracy: 0.0195
# Epoch 324/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0205 - accuracy: 0.2028 - val_loss: 2.3285 - val_accuracy: 0.0175
# Epoch 325/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0155 - accuracy: 0.2053 - val_loss: 2.3469 - val_accuracy: 0.0178
# Epoch 326/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0196 - accuracy: 0.2038 - val_loss: 2.3338 - val_accuracy: 0.0148
# Epoch 327/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0221 - accuracy: 0.2040 - val_loss: 2.3302 - val_accuracy: 0.0180
# Epoch 328/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0153 - accuracy: 0.2054 - val_loss: 2.3212 - val_accuracy: 0.0168
# Epoch 329/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0157 - accuracy: 0.2051 - val_loss: 2.3523 - val_accuracy: 0.0170
# Epoch 330/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0139 - accuracy: 0.2055 - val_loss: 2.3387 - val_accuracy: 0.0170
# Epoch 331/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0154 - accuracy: 0.2049 - val_loss: 2.3386 - val_accuracy: 0.0162
# Epoch 332/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0123 - accuracy: 0.2056 - val_loss: 2.3571 - val_accuracy: 0.0172
# Epoch 333/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0168 - accuracy: 0.2043 - val_loss: 2.3289 - val_accuracy: 0.0160
# Epoch 334/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0153 - accuracy: 0.2045 - val_loss: 2.3316 - val_accuracy: 0.0178
# ...
# Epoch 490/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0042 - accuracy: 0.2081 - val_loss: 2.4467 - val_accuracy: 0.0170
# Epoch 491/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0023 - accuracy: 0.2084 - val_loss: 2.4425 - val_accuracy: 0.0175
# Epoch 492/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0033 - accuracy: 0.2081 - val_loss: 2.4555 - val_accuracy: 0.0182
# Epoch 493/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0050 - accuracy: 0.2079 - val_loss: 2.4665 - val_accuracy: 0.0175
# Epoch 494/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 0.2080 - val_loss: 2.4591 - val_accuracy: 0.0178
# Epoch 495/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0028 - accuracy: 0.2081 - val_loss: 2.4351 - val_accuracy: 0.0180
# Epoch 496/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 0.2084 - val_loss: 2.4640 - val_accuracy: 0.0165
# Epoch 497/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0015 - accuracy: 0.2086 - val_loss: 2.4526 - val_accuracy: 0.0175
# Epoch 498/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0026 - accuracy: 0.2085 - val_loss: 2.4460 - val_accuracy: 0.0168
# Epoch 499/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2082 - val_loss: 2.4569 - val_accuracy: 0.0170
# Epoch 500/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 0.2088 - val_loss: 2.4641 - val_accuracy: 0.0160
# Epoch 501/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2083 - val_loss: 2.4537 - val_accuracy: 0.0175
# Epoch 502/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0043 - accuracy: 0.2077 - val_loss: 2.4577 - val_accuracy: 0.0175
# Epoch 503/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0038 - accuracy: 0.2081 - val_loss: 2.4544 - val_accuracy: 0.0172
# Epoch 504/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0040 - accuracy: 0.2080 - val_loss: 2.4598 - val_accuracy: 0.0172
# Epoch 505/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0018 - accuracy: 0.2083 - val_loss: 2.4759 - val_accuracy: 0.0168
# Epoch 506/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0020 - accuracy: 0.2084 - val_loss: 2.4628 - val_accuracy: 0.0180
# Epoch 507/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0039 - accuracy: 0.2081 - val_loss: 2.4637 - val_accuracy: 0.0162
# Epoch 508/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0030 - accuracy: 0.2081 - val_loss: 2.4597 - val_accuracy: 0.0170
# Epoch 509/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0032 - accuracy: 0.2080 - val_loss: 2.4729 - val_accuracy: 0.0160
# Epoch 510/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0028 - accuracy: 0.2084 - val_loss: 2.4671 - val_accuracy: 0.0168
# Epoch 511/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0023 - accuracy: 0.2082 - val_loss: 2.4753 - val_accuracy: 0.0165
# Epoch 512/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0026 - accuracy: 0.2082 - val_loss: 2.4774 - val_accuracy: 0.0160
# Epoch 513/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0018 - accuracy: 0.2083 - val_loss: 2.4818 - val_accuracy: 0.0153
# Epoch 514/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0033 - accuracy: 0.2080 - val_loss: 2.4745 - val_accuracy: 0.0162
# Epoch 515/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0046 - accuracy: 0.2085 - val_loss: 2.4636 - val_accuracy: 0.0155
# Epoch 516/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0033 - accuracy: 0.2082 - val_loss: 2.4810 - val_accuracy: 0.0162
# Epoch 517/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0012 - accuracy: 0.2088 - val_loss: 2.4962 - val_accuracy: 0.0162
# Epoch 518/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0036 - accuracy: 0.2083 - val_loss: 2.4816 - val_accuracy: 0.0153
# Epoch 519/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.4879 - val_accuracy: 0.0158
# Epoch 520/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0050 - accuracy: 0.2079 - val_loss: 2.4695 - val_accuracy: 0.0158
# Epoch 521/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 0.2078 - val_loss: 2.4625 - val_accuracy: 0.0165
# Epoch 522/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0032 - accuracy: 0.2081 - val_loss: 2.4810 - val_accuracy: 0.0170
# Epoch 523/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2086 - val_loss: 2.4894 - val_accuracy: 0.0158
# Epoch 524/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2082 - val_loss: 2.4867 - val_accuracy: 0.0160
# Epoch 525/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0029 - accuracy: 0.2084 - val_loss: 2.4751 - val_accuracy: 0.0168
# Epoch 526/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0030 - accuracy: 0.2084 - val_loss: 2.4963 - val_accuracy: 0.0158
# Epoch 527/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0031 - accuracy: 0.2083 - val_loss: 2.4831 - val_accuracy: 0.0158
# Epoch 528/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2083 - val_loss: 2.4892 - val_accuracy: 0.0148
# Epoch 529/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0025 - accuracy: 0.2083 - val_loss: 2.4889 - val_accuracy: 0.0165
# Epoch 530/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0025 - accuracy: 0.2083 - val_loss: 2.4842 - val_accuracy: 0.0180
# Epoch 531/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0036 - accuracy: 0.2079 - val_loss: 2.4876 - val_accuracy: 0.0170
# Epoch 532/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2083 - val_loss: 2.4982 - val_accuracy: 0.0162
# Epoch 533/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 0.2085 - val_loss: 2.4856 - val_accuracy: 0.0170
# Epoch 534/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0020 - accuracy: 0.2086 - val_loss: 2.5050 - val_accuracy: 0.0155
# Epoch 535/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 0.2088 - val_loss: 2.5183 - val_accuracy: 0.0168
# Epoch 536/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0028 - accuracy: 0.2084 - val_loss: 2.5084 - val_accuracy: 0.0172
# Epoch 537/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0023 - accuracy: 0.2084 - val_loss: 2.4806 - val_accuracy: 0.0170
# Epoch 538/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0018 - accuracy: 0.2086 - val_loss: 2.4666 - val_accuracy: 0.0185
# Epoch 539/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0020 - accuracy: 0.2084 - val_loss: 2.4862 - val_accuracy: 0.0162
# Epoch 540/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0016 - accuracy: 0.2087 - val_loss: 2.4982 - val_accuracy: 0.0168
# Epoch 541/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0027 - accuracy: 0.2084 - val_loss: 2.4932 - val_accuracy: 0.0160
# Epoch 542/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0022 - accuracy: 0.2087 - val_loss: 2.4873 - val_accuracy: 0.0168
# Epoch 543/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.4894 - val_accuracy: 0.0178
# Epoch 544/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0018 - accuracy: 0.2087 - val_loss: 2.4927 - val_accuracy: 0.0195
# Epoch 545/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0021 - accuracy: 0.2086 - val_loss: 2.5098 - val_accuracy: 0.0178
# Epoch 546/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0033 - accuracy: 0.2084 - val_loss: 2.5239 - val_accuracy: 0.0162
# Epoch 547/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0082 - accuracy: 0.2072 - val_loss: 2.4819 - val_accuracy: 0.0172
# Epoch 548/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.5004 - val_accuracy: 0.0150
# Epoch 549/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0020 - accuracy: 0.2086 - val_loss: 2.4845 - val_accuracy: 0.0160
# Epoch 550/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0035 - accuracy: 0.2080 - val_loss: 2.4909 - val_accuracy: 0.0145
# Epoch 551/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0025 - accuracy: 0.2083 - val_loss: 2.4615 - val_accuracy: 0.0162
# Epoch 552/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0027 - accuracy: 0.2084 - val_loss: 2.4895 - val_accuracy: 0.0162
# Epoch 553/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0047 - accuracy: 0.2078 - val_loss: 2.5018 - val_accuracy: 0.0162
# Epoch 554/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0057 - accuracy: 0.2076 - val_loss: 2.4694 - val_accuracy: 0.0165
# Epoch 555/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0024 - accuracy: 0.2086 - val_loss: 2.4932 - val_accuracy: 0.0195
# Epoch 556/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 0.2087 - val_loss: 2.4962 - val_accuracy: 0.0190
# Epoch 557/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0018 - accuracy: 0.2086 - val_loss: 2.4909 - val_accuracy: 0.0180
# Epoch 558/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2087 - val_loss: 2.5071 - val_accuracy: 0.0172
# Epoch 559/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0045 - accuracy: 0.2080 - val_loss: 2.4864 - val_accuracy: 0.0172
# Epoch 560/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0037 - accuracy: 0.2081 - val_loss: 2.4794 - val_accuracy: 0.0165
# Epoch 561/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 0.2087 - val_loss: 2.4841 - val_accuracy: 0.0158
# Epoch 562/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0023 - accuracy: 0.2086 - val_loss: 2.4829 - val_accuracy: 0.0170
# Epoch 563/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0033 - accuracy: 0.2081 - val_loss: 2.4880 - val_accuracy: 0.0158
# Epoch 564/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 0.2086 - val_loss: 2.4878 - val_accuracy: 0.0155
# Epoch 565/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0026 - accuracy: 0.2086 - val_loss: 2.4565 - val_accuracy: 0.0165
# Epoch 566/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0041 - accuracy: 0.2082 - val_loss: 2.4550 - val_accuracy: 0.0178
# Epoch 567/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0023 - accuracy: 0.2084 - val_loss: 2.4905 - val_accuracy: 0.0170
# Epoch 568/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0047 - accuracy: 0.2082 - val_loss: 2.4745 - val_accuracy: 0.0172
# Epoch 569/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0014 - accuracy: 0.2085 - val_loss: 2.4743 - val_accuracy: 0.0168
# Epoch 570/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 0.2086 - val_loss: 2.4747 - val_accuracy: 0.0182
# Epoch 571/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0015 - accuracy: 0.2086 - val_loss: 2.4908 - val_accuracy: 0.0175
# Epoch 572/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.5012 - val_accuracy: 0.0185
# Epoch 573/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0010 - accuracy: 0.2087 - val_loss: 2.4965 - val_accuracy: 0.0170
# Epoch 574/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0035 - accuracy: 0.2081 - val_loss: 2.4969 - val_accuracy: 0.0170
# Epoch 575/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0035 - accuracy: 0.2083 - val_loss: 2.4933 - val_accuracy: 0.0160
# Epoch 576/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0012 - accuracy: 0.2085 - val_loss: 2.4803 - val_accuracy: 0.0168
# Epoch 577/600
# 32/32 [==============================] - 0s 16ms/step - loss: 9.9122e-04 - accuracy: 0.2087 - val_loss: 2.4994 - val_accuracy: 0.0175
# Epoch 578/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0032 - accuracy: 0.2083 - val_loss: 2.4975 - val_accuracy: 0.0192
# Epoch 579/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.5027 - val_accuracy: 0.0180
# Epoch 580/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0010 - accuracy: 0.2088 - val_loss: 2.5058 - val_accuracy: 0.0178
# Epoch 581/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 0.2087 - val_loss: 2.4947 - val_accuracy: 0.0190
# Epoch 582/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0035 - accuracy: 0.2083 - val_loss: 2.4908 - val_accuracy: 0.0190
# Epoch 583/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0033 - accuracy: 0.2082 - val_loss: 2.4960 - val_accuracy: 0.0178
# Epoch 584/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0027 - accuracy: 0.2086 - val_loss: 2.5030 - val_accuracy: 0.0172
# Epoch 585/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0019 - accuracy: 0.2084 - val_loss: 2.5129 - val_accuracy: 0.0170
# Epoch 586/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0039 - accuracy: 0.2081 - val_loss: 2.5158 - val_accuracy: 0.0190
# Epoch 587/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0027 - accuracy: 0.2085 - val_loss: 2.4990 - val_accuracy: 0.0188
# Epoch 588/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0021 - accuracy: 0.2084 - val_loss: 2.5070 - val_accuracy: 0.0192
# Epoch 589/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0030 - accuracy: 0.2083 - val_loss: 2.4822 - val_accuracy: 0.0182
# Epoch 590/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 0.2084 - val_loss: 2.5040 - val_accuracy: 0.0188
# Epoch 591/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 0.2085 - val_loss: 2.4826 - val_accuracy: 0.0165
# Epoch 592/600
# 32/32 [==============================] - 0s 15ms/step - loss: 9.9738e-04 - accuracy: 0.2087 - val_loss: 2.5002 - val_accuracy: 0.0188
# Epoch 593/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0046 - accuracy: 0.2082 - val_loss: 2.4910 - val_accuracy: 0.0162
# Epoch 594/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0013 - accuracy: 0.2087 - val_loss: 2.4897 - val_accuracy: 0.0165
# Epoch 595/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0021 - accuracy: 0.2084 - val_loss: 2.4841 - val_accuracy: 0.0180
# Epoch 596/600
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0032 - accuracy: 0.2082 - val_loss: 2.4863 - val_accuracy: 0.0175
# Epoch 597/600
# 32/32 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 0.2087 - val_loss: 2.4986 - val_accuracy: 0.0175
# Epoch 598/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0018 - accuracy: 0.2086 - val_loss: 2.5087 - val_accuracy: 0.0175
# Epoch 599/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 0.2086 - val_loss: 2.4994 - val_accuracy: 0.0175
# Epoch 600/600
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 0.2084 - val_loss: 2.5015 - val_accuracy: 0.0188

# %%
from keras.models import load_model
training_model = load_model('training_model.h5')
encoder_inputs = training_model.input[0]
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[2].output
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

latent_dim = 256
decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]
decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_hidden, state_cell]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

def decode_response(test_input):
    #Getting the output states to pass into the decoder
    states_value = encoder_model.predict(test_input)
    #Generating empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    #Setting the first token of target sequence with the start token
    target_seq[0, 0, target_features_dict['<START>']] = 1.
    
    #A variable to store our response word by word
    decoded_sentence = ''
    
    stop_condition = False
    while not stop_condition:
      #Predicting output tokens with probabilities and states
      output_tokens, hidden_state, cell_state = decoder_model.predict([target_seq] + states_value)
      
# Choosing the one with highest probability -> huristic : greedy search decoder
      sampled_token_index = np.argmax(output_tokens[0, -1, :])
    #  temp = np.argsort(output_tokens[0, -1, :])[-15:][::-1]    
      sampled_token = reverse_target_features_dict[sampled_token_index]
      decoded_sentence += " " + sampled_token
#Stop if hit max length or found the stop token
      if (sampled_token == '<END>' or len(decoded_sentence) > max_decoder_seq_length):
        stop_condition = True
#Update the target sequence
      target_seq = np.zeros((1, 1, num_decoder_tokens))
      target_seq[0, 0, sampled_token_index] = 1.
      #Update states
      states_value = [hidden_state, cell_state]
    return decoded_sentence

# %%
class ChatBot:
  negative_responses = ("no", "nope", "nah", "naw", "not a chance", "sorry")
  exit_commands = ("quit", "pause", "exit", "goodbye", "bye", "later", "stop")#Method to start the conversation
  def start_chat(self):
    user_response = input("Hi, I'm a chatbot trained on random dialogs. Would you like to chat with me?\n")
    
    if user_response in self.negative_responses:
      print("Ok, have a great day!")
      return
    self.chat(user_response)#Method to handle the conversation
  def chat(self, reply):
    while not self.make_exit(reply):
      reply = input(self.generate_response(reply)+"\n")
    
  #Method to convert user input into a matrix
  def string_to_matrix(self, user_input):
    tokens = re.findall(r"[\w']+|[^\s\w]", user_input)
    user_input_matrix = np.zeros(
      (1, max_encoder_seq_length, num_encoder_tokens),
      dtype='float32')
    for timestep, token in enumerate(tokens):
      if token in input_features_dict:
        user_input_matrix[0, timestep, input_features_dict[token]] = 1.
    return user_input_matrix
  
  #Method that will create a response using seq2seq model we built
  def generate_response(self, user_input):
    input_matrix = self.string_to_matrix(user_input)
    chatbot_response = decode_response(input_matrix)
    #Remove <START> and <END> tokens from chatbot_response
    chatbot_response = chatbot_response.replace("<START>",'')
    chatbot_response = chatbot_response.replace("<END>",'')
    return chatbot_response#Method to check for exit commands
  def make_exit(self, reply):
    for exit_command in self.exit_commands:
      if exit_command in reply:
        print("Ok, have a great day!")
        return True
    return False
  
chatbot = ChatBot()
chatbot.start_chat()
# Out:
# Hi, I'm a chatbot trained on random dialogs. Would you like to chat with me?
# hi
#  hi there how are you
# i'm fine
#  microsoft is getting really strong on ai so you can
# thats nice
#  how is work going today
# i am really busy today
#  i m super and you
# :)
#  smile
# :(
#  smile
# i have exams
#  smile
# whats your name
#  maybe you want to say thanks
# why should i thank you
#  hahah nice emacs even have games
# ok bye
# Ok, have a great day!

# %%
training_model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None, 981)]  0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None, 1003)] 0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 256), (None, 1267712     input_3[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  1290240     input_4[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 1003)   257771      lstm_3[0][0]
# ==================================================================================================
# Total params: 2,815,723
# Trainable params: 2,815,723
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# chatbot.debug("hi there")
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f77e92e2bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# there
# hi
# only
# exactly
# how
# sorry
# do
# and
# i
# if
# is
# <END>
# a
# suggesting
# humans
# is
# how
# it
# something
# what
# soon
# important
# answers
# called
# m
# i
# yes
# persons
# <END>
# have
# something
# fine
# the
# how
# <END>
# widely
# work
# true
# happy
# violent
# rdany
# 93
# want
# did
# it
# preventing
# if
# fine
# to
# used
# grow
# basic
# when
# you
# on
# going
# mostly
# something
# say
# all
# you
# something
# scientific
# <END>
# today
# learn
# with
# going
# this
# all
# keep
# mostly
# by
# called
# preventing
# from
# make
# thanks
# want
# doing
# <END>
# like
# going
# on
# basic
# scientific
# today
# do
# me
# need
# doing
# your
# going
# <END>
# by
# from
# on
# itself
# charging
# nothing
# programming
# friedrich
# judge
# i
# call
# that
# <END>
# some
# thanks
# doing
# to
# and
# coding
# was
# how
# me
# are
# by
# i
# there
# <END>
# coding
# maybe
# is
# every
# by
# change
# makes
# day
# the
# you
# one
# time
# also
# how
# array([[[0., 0., 0., ..., 0., 0., 0.]]])
